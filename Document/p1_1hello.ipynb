# %% [markdown]
# #### **<font color="blue">【实战1-1】AI实战环境搭建</font>**
# **任务：**
# 1、参考语雀笔记《Windows AI实战环境搭建》，进行AI实战环境搭建。
# 2、编写你的第一个python程序，测试你的AI实战环境。我们是在jupyter lab中编写python代码，文件后缀是.ipynb。
# 要求实现：
# 1）使用print()输出hello, ai；
# 2）使用pandas的read_csv()函数加载数据'data.csv'，并赋值给变量data；
# 3）使用print()输出data。

# %%
print('hello, ai')
# Out:
# hello, ai

# %% [markdown]
# ## 文件路径的写法
# 相对路径：文件data.csv相对文件p1_1hello.ipynb的路径
# 绝对路径：文件data.csv从盘符开始的路径
# r'dataset\data.csv'表示这是一个原始字符串（raw string），反斜杠\不会被当作转义字符，而是当作普通字符处理。

# %%
import pandas as pd  # 引入python的第三方库pandas，pd是别名，写起来更方便
# data = pd.read_csv(r'dataset\data.csv')  # 相对路径
data = pd.read_csv(r'D:\zhangsan\projects\dataset\data.csv') #绝对路径
print(data)
# Out:
#      x    y
# 0  -10  100
# 1   -9   81
# 2   -8   64
# 3   -7   49
# 4   -6   36
# 5   -5   25
# 6   -4   16
# 7   -3    9
# 8   -2    4
# 9   -1    1
# 10   0    0
# 11   1    1
# 12   2    4
# 13   3    9
# 14   4   16
# 15   5   25
# 16   6   36
# 17   7   49
# 18   8   64
# 19   9   81
# 20  10  100
