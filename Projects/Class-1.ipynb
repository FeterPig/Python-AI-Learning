# %% [markdown]
# 1）使用print()输出hello, ai；

# %%
print("hello, ai")
# Out:
# hello, ai

# %% [markdown]
# 2）使用pandas的read_csv()函数加载数据'data.csv'，并赋值给变量data；

# %%
import pandas as pd
data = pd.read_csv("../data/data.csv")

# %% [markdown]
# 3）使用print()输出data。

# %%
print(data)
# Out:
#      x    y
# 0  -10  100
# 1   -9   81
# 2   -8   64
# 3   -7   49
# 4   -6   36
# 5   -5   25
# 6   -4   16
# 7   -3    9
# 8   -2    4
# 9   -1    1
# 10   0    0
# 11   1    1
# 12   2    4
# 13   3    9
# 14   4   16
# 15   5   25
# 16   6   36
# 17   7   49
# 18   8   64
# 19   9   81
# 20  10  100
